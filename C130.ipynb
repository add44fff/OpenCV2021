# %% [markdown]
# ## 1.3.1 Basic Operations on Images

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
def pltImage(img):
    plt.imshow(img)
    plt.xticks([]), plt.yticks([]) # to hide tick values on X and Y axis
    plt.show()

# %%
img = cv2.imread('CX8iXq-WMAA5WeR.jpg')
px = img[100,100]
print (px)
# Out:
# [30 25 26]

# %%
pltImage(img)

# %%
blue = img[100,100,0]
print(blue)
# Out:
# 30

# %%
img[100,100] = [255,255,255]
pltImage(img)

# %%
img.shape
# Out:
# (1024, 1024, 3)

# %%
img.size
# Out:
# 3145728

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
w=1
img[280:(340+w), 330:(390+w)] = ball#Region of interest

# %%
pltImage(ball)

# %%
ball = img[10:10+w, 10:10+w]

# %%
pltImage(img)

# %%
b,g,r = cv2.split(img)

# %%
b.shape
# Out:
# (1024, 1024)

# %%
b
# Out:
# array([[ 31,  31,  32, ...,  85,  41,  86],
#        [ 32,  32,  32, ...,  79,  75, 155],
#        [ 34,  33,  33, ..., 110, 124, 112],
#        ...,
#        [240, 240, 241, ..., 176, 178, 182],
#        [242, 243, 243, ..., 175, 176, 184],
#        [244, 244, 245, ..., 175, 178, 188]], dtype=uint8)

# %%
g
# Out:
# array([[ 25,  25,  26, ...,  72,  28,  73],
#        [ 26,  26,  26, ...,  66,  62, 142],
#        [ 28,  27,  27, ...,  97, 111,  99],
#        ...,
#        [242, 242, 243, ..., 189, 191, 195],
#        [244, 245, 245, ..., 188, 191, 199],
#        [246, 246, 247, ..., 188, 193, 203]], dtype=uint8)

# %%
r
# Out:
# array([[ 26,  26,  27, ...,  64,  20,  65],
#        [ 27,  27,  27, ...,  58,  54, 134],
#        [ 29,  28,  28, ...,  89, 103,  91],
#        ...,
#        [236, 236, 237, ..., 191, 193, 197],
#        [238, 239, 239, ..., 190, 193, 201],
#        [240, 240, 241, ..., 190, 195, 205]], dtype=uint8)

# %%
img = cv2.merge((r,g,b))

# %%
pltImage(img)

# %%
pltImage(r)

# %%
pltImage(g)

# %%
pltImage(b)

# %%
BLUE = [255,0,0]
img1 = cv2.imread('CX8iXq-WMAA5WeR.jpg')
m = 100
replicate = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REPLICATE)
reflect = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REFLECT)
reflect101 = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_REFLECT_101)
wrap = cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_WRAP)
constant= cv2.copyMakeBorder(img1,10,10,10,10,cv2.BORDER_CONSTANT,value=BLUE)

# %%
plt.rcParams["figure.figsize"] = (20,10)
plt.subplot(231),plt.imshow(img1,'gray'),plt.title('ORIGINAL')
plt.subplot(232),plt.imshow(replicate,'gray'),plt.title('REPLICATE')
plt.subplot(233),plt.imshow(reflect,'gray'),plt.title('REFLECT')
plt.subplot(234),plt.imshow(reflect101,'gray'),plt.title('REFLECT_101')
plt.subplot(235),plt.imshow(wrap,'gray'),plt.title('WRAP')
plt.subplot(236),plt.imshow(constant,'gray'),plt.title('CONSTANT')
plt.show()
